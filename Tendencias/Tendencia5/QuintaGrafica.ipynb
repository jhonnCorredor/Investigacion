# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el archivo CSV
archivo_csv = "QuintaTendencia.csv"  # Cambia por la ruta real de tu archivo
df = pd.read_csv(archivo_csv, sep=';')

# Limpiar los datos
df = df.dropna(how='all')  # Eliminar filas completamente vacías

# Mostrar las primeras filas para verificar
df.head()
# Out:
#    Ranking             Job Title  Median Base Salary  Job Satisfaction  \
# 0        1  Enterprise Architect              144997               4.1
# 1        2   Full Stack Engineer              101794               4.3
# 2        3        Data Scientist              120000               4.1
# 3        4       Devops Engineer              120095               4.2
# 4        5      Strategy Manager              140000               4.2
#
#    Job Openings
# 0         14021
# 1         11252
# 2         10071
# 3          8548
# 4          6977

# %%
# Crear un gráfico de barras para el salario base mediano
plt.figure(figsize=(12, 8))  # Tamaño del gráfico

# Crear el gráfico de barras
plt.barh(df['Job Title'], df['Median Base Salary'], color='skyblue')

# Añadir etiquetas y título
plt.xlabel('Salario Base Mediano')
plt.ylabel('Título del Trabajo')
plt.title('Salario Base Mediano por Título de Trabajo')

# Mostrar la gráfica
plt.show()

# %%
# Crear un gráfico de barras para el número de aperturas de empleos
plt.figure(figsize=(12, 8))  # Tamaño del gráfico

# Crear el gráfico de barras
plt.barh(df['Job Title'], df['Job Openings'], color='salmon')

# Añadir etiquetas y título
plt.xlabel('Número de Aperturas de Empleos')
plt.ylabel('Título del Trabajo')
plt.title('Número de Aperturas de Empleos por Título de Trabajo')

# Mostrar la gráfica
plt.show()
